# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv("advertising.csv", sep = ',')

# %%
data
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %% [markdown]
# The outcome of the data displayed in a table showing that we have a total of 200 rows and 4 columns

# %%
data.isna().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %% [markdown]
# This shows that there is no empty element in the data set

# %%
#describe the data
data.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %% [markdown]
# This gives us a brief description of the data set were working with which includes the average,count,min, max and so on

# %%
#are there outliers in the dataset?
sns.scatterplot(x='TV', y='Sales', data=data)
plt.title('TV vs. Sales')
plt.show()

# %% [markdown]
# This is a scatterplot showing the correlation between sales and Tv telling us that as the Tv production increased, more sales were made.

# %%
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %% [markdown]
# This shows the first five set of the data

# %%
data.tail()
# Out:
#         TV  Radio  Newspaper  Sales
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4

# %% [markdown]
# This shows the last five set of the data

# %%
list(data.columns)
# Out:
# ['TV', 'Radio', 'Newspaper', 'Sales']

# %% [markdown]
# This shows the column headings

# %%
result = data[['Radio', 'Newspaper']]
result
# Out:
#      Radio  Newspaper
# 0     37.8       69.2
# 1     39.3       45.1
# 2     45.9       69.3
# 3     41.3       58.5
# 4     10.8       58.4
# ..     ...        ...
# 195    3.7       13.8
# 196    4.9        8.1
# 197    9.3        6.4
# 198   42.0       66.2
# 199    8.6        8.7
#
# [200 rows x 2 columns]

# %%
below_5,d,v,n =data [['TV']], data['Radio'], data[['Newspaper']], data[data['Sales'] < 5]

# data [~below_5]
n
# Out:
#       TV  Radio  Newspaper  Sales
# 8    8.6    2.1        1.0    4.8
# 130  0.7   39.6        8.7    1.6
# 155  4.1   11.6        5.7    3.2

# %% [markdown]
# The outcome shows that the number of rows on Sales that are below_5 making it three rows in all.

# %%
below_30 =data ['Radio'] <30
data [below_30]
# Out:
#         TV  Radio  Newspaper  Sales
# 4    180.8   10.8       58.4   17.9
# 7    120.2   19.6       11.6   13.2
# 8      8.6    2.1        1.0    4.8
# 9    199.8    2.6       21.2   15.6
# 10    66.1    5.8       24.2   12.6
# ..     ...    ...        ...    ...
# 192   17.2    4.1       31.6    5.9
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 199  232.1    8.6        8.7   18.4
#
# [130 rows x 4 columns]

# %% [markdown]
# The outcome shows that the number of rows on Radio that are less than 30 making it 130 rows in all.

# %%
sns.scatterplot(x='Radio', y='Sales', data=data)
plt.title('Radio vs. Sales')
plt.show()

# %% [markdown]
# This is a scatterplot showing the correlation between sales and Radio telling us that as the Radio production increased, more sales were made although not directly.

# %%
sns.scatterplot(x='Newspaper', y='Sales', data=data)
plt.title('Newspaper vs. Sales')
plt.show()

# %% [markdown]
# This is a scatterplot showing the correlation between sales and Newspaper telling us that as the Newspaper production increased, lesser sales were made.

# %%
sns.histplot(data["Sales"]);

# %% [markdown]
# This histogram shows the Sales frequency.

# %%
#are there outliers in the dataset?
plt.figure(figsize=(10,5))
# sns.histplot(x='Newspaper', y='Sales', data=data)
sns.histplot(data=data[['TV','Sales']], alpha=0.5, color='purple',bins =20) 
plt.title('TV Distribution')
plt.xlabel('TV')
plt.ylabel ('Sales')
plt.show()

# %% [markdown]
# This is a bivariant exploration showing how Tv Distribution affects Sales

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=data[['Radio','Sales',"Newspaper"]], bins =20) 
plt.title('Radio and Newspaper Distribution')
plt.xlabel('Radio')
plt.ylabel ('Sales')
plt.show()

# %%
This is a multivariant exploration showing how Radio and Newspaper Distribution affects Sales

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=data[['Newspaper','Sales']], bins =20) 
plt.title('Newspaper Distribution')
plt.xlabel('Newspaper')
plt.ylabel ('Sales')
plt.show()

# %%
#heatmap
sns.heatmap(data.corr(), annot= True, cmap='viridis');

# %%
sns.boxplot(data=data[['Newspaper','Radio','TV', 'Sales',]])
plt.title('Newspaper vs.Radio vs. TV ')
plt.show()

# %%
#keep others on the x-axix and sales stand on the y-axis and 
x ='Newspaper', 'Radio','TV'
y='Sales'
sns.boxplot(data=data[[x=='Newspaper', 'Radio','TV',y=='Sales', annot = True]]) 
sns.boxplot(data=data[['Newspaper','Radio','TV',]])
plt.title('Newspaper vs.Radio vs. TV ')
plt.show()
# Out:
#   Cell In[130], line 4
#     sns.boxplot(data=data[[x=='Newspaper', 'Radio','TV',y=='Sales', annot = True]])
#                                                                     ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
#to remove the sales column
data.iloc[:,:-1]

# %%
#to do
pd.merge()

# %%
data[['Radio']] > data[['Radio']].max()

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=data[['Newspaper',]], bins =20) 
plt.title('Newspaper Distribution')
plt.xlabel('Newspaper')
plt.ylabel ('Frequency')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=data[['Newspaper',]], bins =20) 
#plt.subplot(131)
axes[0,0]
plt.title('Newspaper Distribution')
plt.xlabel('Newspaper')
plt.ylabel ('Frequency')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[108], line 4
#       2 sns.histplot(data=data[['Newspaper',]], bins =20)
#       3 #plt.subplot(131)
# ----> 4 axes[0,0]
#       5 plt.title('Newspaper Distribution')
#       6 plt.xlabel('Newspaper')
#
# NameError: name 'axes' is not defined

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=data[['Radio',]], bins =5) 
plt.title('Radio Distribution')
plt.xlabel('Radio')
plt.ylabel ('Frequency')
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
data[data['TV'] =='10']
# Out:
# Empty DataFrame
# Columns: [TV, Radio, Newspaper, Sales]
# Index: []

# %%
sns.histplot(data["TV"]);

# %%
plt.figure(figsize =(12,12))
plt.subplot(221)
plt.hist(data['TV'], bins=5, color='blue', alpha =0.7)
plt.title('TV Spending Distribution')
plt.xlabel('Tv Spending')
plt.subplot(222)
plt.hist(data['Radio'], bins= 5, color='purple', alpha= 0.7)
plt.title('Radio Spending Distribution')
plt.xlabel('Radio Spending')
plt.subplot(223)
plt.hist(data['Newspaper'], bins= 5, color='green', alpha =0.7)
plt.title('Newspaper Spending Distribution')
plt.xlabel('Newspaper Spending')
plt.subplot(224)
plt.hist(data['Sales'], bins = 5, color ='gray', alpha = 0.7)
plt.title('Sales Distribution')
plt.xlabel('Sales Distribution')
plt.show()

# %%
fig,ax = plt.subplots(nrows = 2, ncols = 2,); figsize =(12,4)
#Histgrams to visualize distributions
ax[0,0].hist(data['TV'], bins=10, color='magenta', alpha =0.7)
ax[0,0].set_title('TV Spending Distribution')
plt.xlabel('TV Spending')
#for radio Distribution
ax[0,1].hist(data['Radio'], bins =10, color='gold', alpha =0.7)
ax[0,1].set_title('Radio Distribution')
plt.xlabel('Radio Spending')
#for Newspaer Distribution
ax[1,0].hist(data['Newspaper'], bins = 10, color ='green', alpha =0.7)
ax[1,0].set_title
# Out:
# <bound method Axes.set_title of <Axes: >>
